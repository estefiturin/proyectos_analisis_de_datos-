# %%
import pandas as pd

stanton = pd.read_csv('datasets/stanton.csv')

stanton
# Out:
#      pitch_type   game_date  release_speed  release_pos_x  release_pos_z  \
# 0            SL  2017-10-01           86.4        -1.0592         5.9057
# 1            FF  2017-10-01           98.1        -1.5517         5.7016
# 2            FT  2017-10-01           97.0        -1.3408         5.6190
# 3            FT  2017-10-01           98.0        -1.4515         5.8013
# 4            FT  2017-10-01           94.2        -0.9315         7.0124
# ...         ...         ...            ...            ...            ...
# 5893         SL  2015-04-06           79.3        -2.8200         5.9933
# 5894         SL  2015-04-06           79.8        -2.6602         6.0066
# 5895         FF  2015-04-06           94.2            NaN            NaN
# 5896         SL  2015-04-06           81.5        -2.7187         5.7605
# 5897         FT  2015-04-06           90.1        -2.5953         6.1202
#
#             player_name  batter  pitcher     events      description  ...  \
# ...
